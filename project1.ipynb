# %% [markdown]
# # Project 1: Simulation of particles in 2D
#
# Here we can experiment with new ideas. Debugging will also be easier in jupyter notebook. If we want we can create a main .py file in the end.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import random as rd
